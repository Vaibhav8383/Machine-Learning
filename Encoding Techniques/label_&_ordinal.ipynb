# %% [markdown]
# ### Label And Ordinal Encoding

# %%
import pandas as pd

# %%
from sklearn.preprocessing import LabelEncoder

# %%
#create a sample dataframe with a categorical variables
df = pd.DataFrame({
    'color': ['red','blue','green','green','red','blue']
})

# %%
df
# Out:
#    color
# 0    red
# 1   blue
# 2  green
# 3  green
# 4    red
# 5   blue

# %%
## create an instance of label encoder 
encoder = LabelEncoder()

# %%
encoder.fit_transform(df[['color']])
# Out:
# c:\Users\Vaibhav\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\preprocessing\_label.py:120: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([2, 0, 1, 1, 2, 0])

# %%
## Ordinal Encoding
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder

##create a sample dataframe with a categorical variables
df = pd.DataFrame({
    'size': ['small','medium','large','medium','small','large']
})

# %%
## create an instance of the Ordinal encoder
encoder = OrdinalEncoder(categories=[['small','medium','large']])

# %%
encoder.fit_transform(df[['size']])
# Out:
# array([[0.],
#        [1.],
#        [2.],
#        [1.],
#        [0.],
#        [2.]])
